# %%
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# # distribution plots

# %%
tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=10)

# %%
sns.jointplot(data=tips, x='total_bill',y='tip',kind='hex')
#different kind = "scatter" | "reg" | "resid" | "kde" | "hex"

# %%
sns.pairplot(tips,hue='sex',palette='Accent')

# %%
sns.rugplot(tips['total_bill'],height=0.3)

# %%
sns.distplot(tips['total_bill'])

# %%
tips['total_bill'].std()
# Out:
# 8.902411954856856

# %%
tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
# distplots, jointplot, pairplot, rugplot

# %% [markdown]
# # Categorical plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# This code is for allow notebook to print multiple commands

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips)

# %%
sns.barplot(x='day',y='total_bill',data=tips, hue='sex')

# %%
import numpy as np

# %%
sns.barplot(x='day',y='total_bill',data=tips, hue='sex', estimator=np.sum)

# %%
sns.barplot(x='day',y='total_bill',data=tips, hue='sex', estimator=np.std)

# %%
#countplot is same as like pandas count for given column
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='size',data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')
